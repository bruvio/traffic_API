# %%
import pandas as pd

# %%
traffic_df = pd.read_csv('traffic_data.csv')
pd.set_option('display.max_columns', None)
# pd.set_option("max_rows", None)

# %%
traffic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 922701 entries, 0 to 922700
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   id                            922701 non-null  int64
#  1   count_point_id                922701 non-null  int64
#  2   year                          922701 non-null  int64
#  3   region_id                     922701 non-null  int64
#  4   local_authority_id            922701 non-null  int64
#  5   road_name                     922701 non-null  object
#  6   road_category                 922701 non-null  object
#  7   road_type                     922701 non-null  object
#  8   start_junction_road_name      703164 non-null  object
#  9   end_junction_road_name        703179 non-null  object
#  10  easting                       922701 non-null  int64
#  11  northing                      922701 non-null  int64
# ...

# %%
traffic_df.describe()
# Out:
#                   id  count_point_id           year      region_id  \
# count  922701.000000   922701.000000  922701.000000  922701.000000
# mean   461351.000000   255077.399560    2010.476071       5.924514
# std    266360.979703   375185.408318       6.030152       3.015670
# min         1.000000       51.000000    2000.000000       1.000000
# 25%    230676.000000    28417.000000    2005.000000       3.000000
# 50%    461351.000000    57789.000000    2010.000000       6.000000
# 75%    692026.000000    99588.000000    2016.000000       9.000000
# max    922701.000000   999999.000000    2020.000000      11.000000
#
#        local_authority_id        easting      northing       latitude  \
# count       922701.000000  922701.000000  9.227010e+05  922701.000000
# mean            98.272219  421786.683051  3.272093e+05      52.832733
# std             53.260445   98891.751880  1.834825e+05       1.650221
# min              1.000000   65412.000000  1.021700e+04      49.912239
# ...

# %%
traffic_df.head(100)
# Out:
#      id  count_point_id  year  region_id  local_authority_id road_name  \
# 0     1           75030  2001          9                 142      A420
# 1     2           75030  2001          9                 142      A420
# 2     3           48240  2001         10                  69      A438
# 3     4           48315  2001          9                  80       M20
# 4     5           48365  2001          9                  80     A2034
# ..  ...             ...   ...        ...                 ...       ...
# 95   96           57382  2001          5                  77      A596
# 96   97           57389  2001          5                 161     A5052
# 97   98           57389  2001          5                 161     A5052
# 98   99           48479  2001          7                  78      A119
# 99  100           48479  2001          7                  78      A119
#
#    road_category road_type start_junction_road_name end_junction_road_name  \
# ...

# %%
traffic_df['easting'][0:2]
# Out:
# 0    451300
# 1    451300
# Name: easting, dtype: int64

# %%
traffic_df[0:2]
# Out:
#    id  count_point_id  year  region_id  local_authority_id road_name  \
# 0   1           75030  2001          9                 142      A420
# 1   2           75030  2001          9                 142      A420
#
#   road_category road_type start_junction_road_name end_junction_road_name  \
# 0            PA     Major        A4144 St Aldgates           Speedwell St
# 1            PA     Major        A4144 St Aldgates           Speedwell St
#
#    easting  northing   latitude  longitude  link_length_km  link_length_miles  \
# 0   451300    205650  51.747209  -1.258334             0.3               0.19
# 1   451300    205650  51.747209  -1.258334             0.3               0.19
#
#    sequence  ramp estimation_method estimation_method_detailed  \
# 0     306.0   NaN           Counted               Manual count
# 1     306.0   NaN           Counted               Manual count
#
#   direction_of_travel  pedal_cycles  two_wheeled_motor_vehicles  \
# ...

# %%
import geopandas


df = geopandas.read_file('Wards_(May_2021)_UK_BFE.geojson')
# Out:
# /home/bruvio/Dropbox/work/bruvio_stuff/traffic-API-CityScience/.venv/lib/python3.8/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
df.describe()
# Out:
#           OBJECTID          BNG_E         BNG_N         LONG          LAT  \
# count  8694.000000    8694.000000  8.694000e+03  8694.000000  8694.000000
# mean   4347.500000  413035.959282  3.016592e+05    -1.833034    52.598456
# std    2509.885954  122269.350411  1.592032e+05     1.821214     1.427813
# min       1.000000   10133.000000  7.974000e+03    -8.011500    49.890440
# 25%    2174.250000  340100.000000  1.796750e+05    -2.903812    51.503118
# 50%    4347.500000  425459.500000  2.720980e+05    -1.615230    52.337045
# 75%    6520.750000  511519.750000  3.952275e+05    -0.380265    53.451817
# max    8694.000000  654365.000000  1.192719e+06     1.744734    60.614780
#
#         Shape__Area  Shape__Length
# count  8.694000e+03   8.694000e+03
# mean   2.860639e+07   2.449783e+04
# std    1.205161e+08   4.542851e+04
# min    5.095403e+04   1.015726e+03
# 25%    2.323420e+06   8.185816e+03
# 50%    5.217700e+06   1.290683e+04
# 75%    2.343119e+07   2.929590e+04
# ...

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 8694 entries, 0 to 8693
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OBJECTID       8694 non-null   int64
#  1   WD21CD         8694 non-null   object
#  2   WD21NM         8694 non-null   object
#  3   WD21NMW        8694 non-null   object
#  4   BNG_E          8694 non-null   int64
#  5   BNG_N          8694 non-null   int64
#  6   LONG           8694 non-null   float64
#  7   LAT            8694 non-null   float64
#  8   Shape__Area    8694 non-null   float64
#  9   Shape__Length  8694 non-null   float64
#  10  geometry       8694 non-null   geometry
# dtypes: float64(4), geometry(1), int64(3), object(3)
# memory usage: 747.3+ KB

# %%
df.geometry[0]

# %%
traffic_df.head()
# Out:
#    id  count_point_id  year  region_id  local_authority_id road_name  \
# 0   1           75030  2001          9                 142      A420
# 1   2           75030  2001          9                 142      A420
# 2   3           48240  2001         10                  69      A438
# 3   4           48315  2001          9                  80       M20
# 4   5           48365  2001          9                  80     A2034
#
#   road_category road_type start_junction_road_name end_junction_road_name  \
# 0            PA     Major        A4144 St Aldgates           Speedwell St
# 1            PA     Major        A4144 St Aldgates           Speedwell St
# 2            PA     Major                    B4211            LA Boundary
# 3            TM     Major                        2                    A20
# 4            PA     Major  Shorncliffe Rd/Manor Rd    A2033 Foresters Way
#
#    easting  northing   latitude  longitude  link_length_km  link_length_miles  \
# ...

# %%
import geoplot

geoplot.polyplot(df, figsize=(8, 4))
# Out:
# /home/bruvio/Dropbox/work/bruvio_stuff/traffic-API-CityScience/.venv/lib/python3.8/site-packages/geoplot/geoplot.py:885: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for subgeom in geom:
# <AxesSubplot:>

# %%
import geoplot.crs as gcrs
ax = geoplot.polyplot(df, projection=gcrs.Orthographic(), figsize=(8, 4))
ax.set_global()
ax.outline_patch.set_visible(True)

# %%
geoplot.choropleth(df, hue='gdp_pp', cmap='Greens', figsize=(8, 4))
